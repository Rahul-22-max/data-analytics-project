# %%
import pandas as pd
import numpy as np
import joblib
import shap
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../Data/raw/Telco-Customer-Churn.csv")

df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce").fillna(0)

df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
churn_model = joblib.load("../models/churn_model.pkl")

churn_model
# Out:
# LogisticRegression(max_iter=2000, solver='liblinear')

# %%
# Prepare input features using the same schema used to train the model.

df_model = df.drop(columns=["customerID", "Churn"])

cat_cols = [
    "gender",
    "Partner",
    "Dependents",
    "PhoneService",
    "MultipleLines",
    "InternetService",
    "OnlineSecurity",
    "OnlineBackup",
    "DeviceProtection",
    "TechSupport",
    "StreamingTV",
    "StreamingMovies",
    "Contract",
    "PaperlessBilling",
    "PaymentMethod",
]

X = pd.get_dummies(df_model, columns=cat_cols, drop_first=True)
X = X.reindex(columns=churn_model.feature_names_in_, fill_value=0)

X.head()
# Out:
#    gender  SeniorCitizen  tenure  MonthlyCharges  TotalCharges  Partner_Yes  \
# 0       0              0       1           29.85         29.85         True
# 1       0              0      34           56.95       1889.50        False
# 2       0              0       2           53.85        108.15        False
# 3       0              0      45           42.30       1840.75        False
# 4       0              0       2           70.70        151.65        False
#
#    Dependents_Yes  PhoneService_Yes  MultipleLines_No phone service  \
# 0           False             False                            True
# 1           False              True                           False
# 2           False              True                           False
# 3           False             False                            True
# 4           False              True                           False
#
#    MultipleLines_Yes  ...  StreamingTV_No internet service  StreamingTV_Yes  \
# ...

# %%
type(churn_model)
# Out:
# sklearn.linear_model._logistic.LogisticRegression

# %%
# Create the SHAP explainer for a linear/logistic model.

explainer = shap.LinearExplainer(churn_model, X)
# Out:
# Background dataset has 7043 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=7043 when initializing the masker.

# %%
# Generate SHAP values.

sample = X.sample(200, random_state=42)

shap_values = explainer(sample)
shap_values.values = np.asarray(shap_values.values, dtype=float)

# %%
# Summary plot.

shap.plots.beeswarm(shap_values)

# %%
# Feature importance bar plot.

shap.plots.bar(shap_values)

# %%
# Explain a single prediction.

shap.plots.waterfall(shap_values[0])

# %%
# Save the feature importance plot.

plt.figure(figsize=(10, 6))
shap.plots.bar(shap_values, show=False)
plt.savefig("../docs/shap_feature_importance.png", bbox_inches="tight")
plt.close()
