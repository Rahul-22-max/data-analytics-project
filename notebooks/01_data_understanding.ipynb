# %%
import pandas as pd

# load dataset 
df = pd.read_csv(project_root / 'Data' / 'raw' / 'Telco-Customer-Churn.csv')

# %%
#Dataset shape
print("Dataset shape:", df.shape)
# Out:
# Dataset shape: (7043, 21)

# %%
# column names
print("\ncolumns:")
print(df.columns.tolist())
# Out:
# /ncolumns:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 3
#       1 #column names
#       2 print("/ncolumns:")
# ----> 3 print(df.column.tolist())
#
# File c:\Users\acer\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'column'
